# %%
# imports
import matplotlib.pyplot as plt
import os
import numpy as np
import pandas as pd
import seaborn as sns
from scipy import stats
import sys

from dreem_tools import plotting, parse, dataframe
from q_dms_ttr_paper.paths import DATA_PATH

# general figure tweaks
# %matplotlib inline
plt.rcParams["figure.figsize"] = (15, 10)
plt.rcParams["font.size"] = 20
# to fight the theme

# %%
df = pd.read_json(f"{DATA_PATH}/processed/mutations/mttr6_mut_charactization.json")

# %%
df["num_ins"]
# Out:
# 0     0
# 1     0
# 2     0
# 3     0
# 4     0
#      ..
# 94    0
# 95    0
# 96    0
# 97    0
# 98    0
# Name: num_ins, Length: 99, dtype: int64

# %%
df[df['num_ins'] != 0]
# Out:
#              name           r_name          act_seq           act_ss  \
# 12  UAUGG_CCUAAAG             C7.9  AUAUGG&CCUAAAGU  ((..((&))....))
# 42  GAUGG_CCUAAAG  11nt_R_Vc2_30_2  AGAUGG&CCUAAAGU  (...((&)).....)
# 51  UAUGG_CCUAAAC   11nt_R_Vc2_0_2  AUAUGG&CCUAAACU  (...((&)).....)
# 60  AAUGG_CCUGUAC             C7.2  AAAUGG&CCUGUACU  (...((&)).....)
# 74  CAUGG_CCCUAAC             IC3   ACAUGG&CCCUAACU  (...((&)).....)
# 75  GAUGG_CCUACAC            C7.22  AGAUGG&CCUACACU  ((..((&))....))
# 81  AAGGG_CCCUAAC             IC3   AAAGGG&CCCUAACU  (.((((&))))...)
# 86  UAAGG_CCUAAAG  11nt_R_Vc2_48_2  AUAAGG&CCUAAAGU  ((.(((&)))...))
# 87  GAUGG_CCUCCAC            C7.22  AGAUGG&CCUCCACU  ((..((&))....))
# 89  CACGG_CCCUAAC             IC3   ACACGG&CCCUAACU  (...((&)).....)
# 92  GAUGG_CCCUAAG             IC3   AGAUGG&CCCUAAGU  (...((&)).....)
#
#                                                  seq     dg          r_seq  \
# 12  CUAGGAUAUGGUUGAUAUAGGGGAACCUAUAUCAACCUAAAGUCCUAG -11.13  UAUGG_CCUAAAG
# 42  CUAGGAGAUGGAAUGCACAGGGGAACCUGUGCAUUCCUAAAGUCCUAG -10.29  GAUGG_CCUAAAG
# 51  CUAGGAUAUGGAAUGCACAGGGGAACCUGUGCAUUCCUAAACUCCUAG -10.15  UAUGG_CCUAAAC
# 60  CUAGGAAAUGGUUGAUAUAGGGGAACCUAUAUCAACCUGUACUCCUAG -10.00  AAUGG_CCUGUAC
# 74  CUAGGACAUGGAGGGAUCUUGGGAACAAGAUCCCUCCCUAACUCCUAG  -9.71  CAUGG_CCCUAAC
# 75  CUAGGAGAUGGAAUGCACAGGGGAACCUGUGCAUUCCUACACUCCUAG  -9.70  GAUGG_CCUACAC
# 81  CUAGGAAAGGGUUGAUAUAGGGGAACCUAUAUCAACCCUAACUCCUAG  -9.53  AAGGG_CCCUAAC
# 86  CUAGGAUAAGGAAUGCACAGGGGAACCUGUGCAUUCCUAAAGUCCUAG  -9.41  UAAGG_CCUAAAG
# 87  CUAGGAGAUGGAAUGCACAGGGGAACCUGUGCAUUCCUCCACUCCUAG  -9.30  GAUGG_CCUCCAC
# 89  CUAGGACACGGAAUGCACAGGGGAACCUGUGCAUUCCCUAACUCCUAG  -9.24  CACGG_CCCUAAC
# 92  CUAGGAGAUGGAAUGCACAGGGGAACCUGUGCAUUCCCUAAGUCCUAG  -9.12  GAUGG_CCCUAAG
#
#     aligned_seq insertions deletions  num_ins  num_dels  size inserts  \
# 12  CCUAAGUAUGG         []        []        1         0    13    [6A]
# 42  CCUAAGGAUGG         []        []        1         0    13    [6A]
# 51  CCUAAAUAUGG         []        []        1         0    13    [7C]
# 60  CCUGACAAUGG         []        []        1         0    13    [5U]
# 74  CCUAACCAUGG         []        []        1         0    13    [3C]
# 75  CCUAACGAUGG         []        []        1         0    13    [5C]
# 81  CCUAACAAGGG         []        []        1         0    13    [3C]
# 86  CCUAAGUAAGG         []        []        1         0    13    [6A]
# 87  CCUCACGAUGG         []        []        1         0    13    [5C]
# 89  CCUAACCACGG         []        []        1         0    13    [3C]
# 92  CCUAAGGAUGG         []        []        1         0    13    [3C]
#
#     bp_muts    mut_pos        mutations
# 12       []         []               []
# 42       []        [7]            [G7U]
# 51       []        [6]            [A6G]
# 60       []  [4, 6, 7]  [G4A, C6G, A7U]
# 74       []     [6, 7]       [C6G, C7U]
# 75  [GU3CG]     [6, 7]       [C6G, G7U]
# 81       []  [6, 7, 9]  [C6G, A7U, G9U]
# 86       []        [9]            [A9U]
# 87  [GU3CG]  [4, 6, 7]  [C4A, C6G, G7U]
# 89       []  [6, 7, 9]  [C6G, C7U, C9U]
# 92       []        [7]            [G7U]
