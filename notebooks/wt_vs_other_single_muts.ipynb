# %%
# imports
import matplotlib.pyplot as plt
import os
import numpy as np
import pandas as pd
import seaborn as sns
from scipy import stats
import sys

from dreem_tools import plotting, parse

# general figure tweaks
# %matplotlib inline
plt.rcParams["figure.figsize"] = (15, 10)
plt.rcParams["font.size"] = 16
# to fight the theme
plt.rcParams["figure.facecolor"] = "white"

# %%
BASE_DIR = os.path.abspath(os.path.join(os.getcwd(), '..'))
sys.path.append(BASE_DIR)

# %%
from scripts.analysis.titration_fitting import curve_func_new

# %%
DATA_PATH = BASE_DIR + '/data'

# %%
df = pd.read_json(f"{DATA_PATH}/wt_mg_titra.json")
df = df[df['exp_name'] == "2022_07_27_C0117_50mM_NaC_Mg2+_titra_CM"]
df_uucg = pd.read_json(f"{DATA_PATH}/uucg_mg_titra.json")
df_notlr = pd.read_json(f"{DATA_PATH}/no_tlr_mg.json")
df_no_3x3 = pd.read_json(f"{DATA_PATH}/no_3x3_mg_titra.json")
df_h1_longer = pd.read_json(f"{DATA_PATH}/h1_3bp_longer_mg_titra.json")
df_h2_longer = pd.read_json(f"{DATA_PATH}/h2_3bp_longer_mg_titra.json")
df_h3_longer = pd.read_json(f"{DATA_PATH}/h3_3bp_longer_mg_titra.json")

# %% [markdown]
# ## comparision to no 3x3 motif

# %% [markdown]
# ### summary
#
# appears that without 3x3 there is basically no binding

# %% [markdown]
# ### gaaa comparision

# %%
plt.plot(df['mg_conc'], df['gaaa_avg'], marker='o', label='wt')
plt.plot(df_no_3x3['mg_conc'], df_no_3x3['gaaa_avg'], marker='o', label='no 3x3')
plt.plot(df_notlr['mg_conc'], df_notlr['gaaa_avg'], marker='o', label='no tlr')
plt.legend()
plt.title("difference in GAAA motif")
# Out:
# Text(0.5, 1.0, 'difference in GAAA motif')

# %% [markdown]
# ### tlr comparision

# %%
plt.plot(df['mg_conc'], df['tlr'].apply(lambda x : x[4-1]), marker='o', label='wt')
plt.plot(df_uucg['mg_conc'], df_uucg['tlr'].apply(lambda x : x[4-1]), marker='o', label='uucg')
plt.plot(df_no_3x3['mg_conc'], df_no_3x3['tlr'].apply(lambda x : x[4-1]), marker='o', label='no 3x3')
plt.legend()
plt.title("difference in pos 4 TLR")
# Out:
# Text(0.5, 1.0, 'difference in pos 4 TLR')

# %%
POS = 5
plt.plot(df['mg_conc'], df['tlr'].apply(lambda x : x[POS-1]), marker='o', label='wt')
plt.plot(df_uucg['mg_conc'], df_uucg['tlr'].apply(lambda x : x[POS-1]), marker='o', label='uucg')
plt.plot(df_no_3x3['mg_conc'], df_no_3x3['tlr'].apply(lambda x : x[POS-1]), marker='o', label='no 3x3')
plt.legend()
plt.title(f"difference in pos {POS} TLR")
# Out:
# Text(0.5, 1.0, 'difference in pos 5 TLR')

# %%
POS = 8
plt.plot(df['mg_conc'], df['tlr'].apply(lambda x : x[POS-1]), marker='o', label='wt')
plt.plot(df_uucg['mg_conc'], df_uucg['tlr'].apply(lambda x : x[POS-1]), marker='o', label='uucg')
plt.plot(df_no_3x3['mg_conc'], df_no_3x3['tlr'].apply(lambda x : x[POS-1]), marker='o', label='no 3x3')
plt.legend()
plt.title(f"difference in pos {POS} TLR")
# Out:
# Text(0.5, 1.0, 'difference in pos 8 TLR')

# %% [markdown]
# ## h1 3bp longer

# %% [markdown]
# ### gaaa comparision

# %%
plt.plot(df['mg_conc'], df['gaaa_avg'], marker='o', label='wt')
plt.plot(df_h1_longer['mg_conc'], df_h1_longer['gaaa_avg'], marker='o', label='h1 longer')
plt.plot(df_notlr['mg_conc'], df_notlr['gaaa_avg'], marker='o', label='no tlr')
plt.title("difference in GAAA motif")
# Out:
# Text(0.5, 1.0, 'difference in GAAA motif')

# %% [markdown]
# ### tlr comparision

# %%
POS = 4
plt.plot(df['mg_conc'], df['tlr'].apply(lambda x : x[POS-1]), marker='o', label='wt')
plt.plot(df_uucg['mg_conc'], df_uucg['tlr'].apply(lambda x : x[POS-1]), marker='o', label='uucg')
plt.plot(df_h1_longer['mg_conc'], df_h1_longer['tlr'].apply(lambda x : x[POS-1]), marker='o', label='longer h1')
plt.legend()
plt.title(f"difference in pos {POS} TLR")
# Out:
# Text(0.5, 1.0, 'difference in pos 4 TLR')

# %%
POS = 5
plt.plot(df['mg_conc'], df['tlr'].apply(lambda x : x[POS-1]), marker='o', label='wt')
plt.plot(df_uucg['mg_conc'], df_uucg['tlr'].apply(lambda x : x[POS-1]), marker='o', label='uucg')
plt.plot(df_h1_longer['mg_conc'], df_h1_longer['tlr'].apply(lambda x : x[POS-1]), marker='o', label='longer h1')
plt.legend()
plt.title(f"difference in pos {POS} TLR")
# Out:
# Text(0.5, 1.0, 'difference in pos 5 TLR')

# %%
POS = 8
plt.plot(df['mg_conc'], df['tlr'].apply(lambda x : x[POS-1]), marker='o', label='wt')
plt.plot(df_uucg['mg_conc'], df_uucg['tlr'].apply(lambda x : x[POS-1]), marker='o', label='uucg')
plt.plot(df_h1_longer['mg_conc'], df_h1_longer['tlr'].apply(lambda x : x[POS-1]), marker='o', label='longer h1')
plt.legend()
plt.title(f"difference in pos {POS} TLR")
# Out:
# Text(0.5, 1.0, 'difference in pos 8 TLR')

# %% [markdown]
# ## h2 3bp longer

# %%
plt.plot(df['mg_conc'], df['gaaa_avg'], marker='o', label='wt')
plt.plot(df_no_3x3['mg_conc'], df_no_3x3['gaaa_avg'], marker='o', label='no 3x3')
plt.plot(df_h2_longer['mg_conc'], df_h2_longer['gaaa_avg'], marker='o', label='h2 longer')
plt.title("difference in GAAA motif")
# Out:
# Text(0.5, 1.0, 'difference in GAAA motif')

# %%
POS = 4
plt.plot(df['mg_conc'], df['tlr'].apply(lambda x : x[POS-1]), marker='o', label='wt')
plt.plot(df_uucg['mg_conc'], df_uucg['tlr'].apply(lambda x : x[POS-1]), marker='o', label='uucg')
plt.plot(df_h2_longer['mg_conc'], df_h2_longer['tlr'].apply(lambda x : x[POS-1]), marker='o', label='longer h2')
plt.legend()
plt.title(f"difference in pos {POS} TLR")
# Out:
# Text(0.5, 1.0, 'difference in pos 4 TLR')

# %%
POS = 5
plt.plot(df['mg_conc'], df['tlr'].apply(lambda x : x[POS-1]), marker='o', label='wt')
plt.plot(df_uucg['mg_conc'], df_uucg['tlr'].apply(lambda x : x[POS-1]), marker='o', label='uucg')
plt.plot(df_h2_longer['mg_conc'], df_h2_longer['tlr'].apply(lambda x : x[POS-1]), marker='o', label='longer h2')
plt.legend()
plt.title(f"difference in pos {POS} TLR")
# Out:
# Text(0.5, 1.0, 'difference in pos 5 TLR')

# %%
POS = 8
plt.plot(df['mg_conc'], df['tlr'].apply(lambda x : x[POS-1]), marker='o', label='wt')
plt.plot(df_uucg['mg_conc'], df_uucg['tlr'].apply(lambda x : x[POS-1]), marker='o', label='uucg')
plt.plot(df_h2_longer['mg_conc'], df_h2_longer['tlr'].apply(lambda x : x[POS-1]), marker='o', label='longer h2')
plt.legend()
plt.title(f"difference in pos {POS} TLR")
# Out:
# Text(0.5, 1.0, 'difference in pos 8 TLR')

# %% [markdown]
# ## h3 3bp longer

# %%
plt.plot(df['mg_conc'], df['gaaa_avg'], marker='o', label='wt')
plt.plot(df_no_3x3['mg_conc'], df_no_3x3['gaaa_avg'], marker='o', label='no 3x3')
plt.plot(df_h3_longer['mg_conc'], df_h3_longer['gaaa_avg'], marker='o', label='h3 longer')
plt.title("difference in GAAA motif")
# Out:
# Text(0.5, 1.0, 'difference in GAAA motif')

# %%
POS = 4
plt.plot(df['mg_conc'], df['tlr'].apply(lambda x : x[POS-1]), marker='o', label='wt')
plt.plot(df_uucg['mg_conc'], df_uucg['tlr'].apply(lambda x : x[POS-1]), marker='o', label='uucg')
plt.plot(df_h3_longer['mg_conc'], df_h3_longer['tlr'].apply(lambda x : x[POS-1]), marker='o', label='longer h3')
plt.legend()
plt.title(f"difference in pos {POS} TLR")
# Out:
# Text(0.5, 1.0, 'difference in pos 4 TLR')

# %%
POS = 5
plt.plot(df['mg_conc'], df['tlr'].apply(lambda x : x[POS-1]), marker='o', label='wt')
plt.plot(df_uucg['mg_conc'], df_uucg['tlr'].apply(lambda x : x[POS-1]), marker='o', label='uucg')
plt.plot(df_h3_longer['mg_conc'], df_h3_longer['tlr'].apply(lambda x : x[POS-1]), marker='o', label='longer h3')
plt.legend()
plt.title(f"difference in pos {POS} TLR")
# Out:
# Text(0.5, 1.0, 'difference in pos 5 TLR')

# %%
POS = 8
plt.plot(df['mg_conc'], df['tlr'].apply(lambda x : x[POS-1]), marker='o', label='wt')
plt.plot(df_uucg['mg_conc'], df_uucg['tlr'].apply(lambda x : x[POS-1]), marker='o', label='uucg')
plt.plot(df_h3_longer['mg_conc'], df_h3_longer['tlr'].apply(lambda x : x[POS-1]), marker='o', label='longer h3')
plt.legend()
plt.title(f"difference in pos {POS} TLR")
# Out:
# Text(0.5, 1.0, 'difference in pos 8 TLR')
